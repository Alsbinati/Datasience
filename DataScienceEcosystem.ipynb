# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# In the below lines you will be able to:
# + Identify the three most popular data science languages
# + Add Comments to code cell
# + Create markdown cells
# + Add ordered and unordered to markdown cells
# + Identify the most popular libraries
# + List down the most popular tools used by expert in the field

# %% [markdown]
# Some of the popular languages that Data Scientists use are:

# %% [markdown]
# 1. Python
# 2. Julia
# 3. R
# 4. C++
# 5. JAVA
# 6. JAVAScript
# 7. php
# 8. Go
# 9. Ruby
# 10. Visual Basic
# 11. SQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. Numpy
# 3. Matplotlib
# 4. Seaborn
# 5. Scikit-learn
# 6. Keras
# 7. TensorFlow
# 8. PyTorch
# 9. Apache Spark
# 10. Vegas
# 11. Big DL
# 12. Ggplot2

# %% [markdown]
# |Data Science Tools|
# |------------------|
# |Jupyter Notebooks|
# |Anaconda|
# |Spyder|
# |Zeppelin|
# |R Studio|
# |Google Collaboratory|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
#This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
#This will convert 200 minutes to hours by diving by 60
200//60
# Out:
# 3

# %% [markdown]
# ## Author(s):
# Ahmad Alsbinati
#
# Laksmi Holla
